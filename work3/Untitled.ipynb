# %%
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv("data.tsv",delimiter="\t", header=None)
df.head()
# Out:
#        0         1            2         3         4      5
# 0  100.0  2.000000   477.750000  3.464102  3.464102     10
# 1   50.0  4.250000   975.496844  1.477098  1.596796  10001
# 2  100.0  3.214286  3747.113679  1.022928  0.984565  15577
# 3  100.0  3.153846  4906.374000  0.831080  0.858073  22042
# 4  100.0  4.000000   132.100000  3.464102  3.464102  22227

# %%
data = df.values
data.shape
# Out:
# (1701, 6)

# %%
data = data / data.max(axis=0)
data.shape
# Out:
# (1701, 6)

# %%
def min_dist(clusters):
    m_d = 10000000
    for c1 in clusters:
        for c2 in clusters:
            if not c2 == c1:
                for x1 in clusters[c1]:
                    for x2 in clusters[c2]:
                        d = np.linalg.norm(x1-x2)
                        if d < m_d:
                            m_d = d
                    
    return m_d

def max_dist(clusters):
    m_d = 0
    for c1 in clusters:
        for c2 in clusters:
            if not c2 == c1:
                for x1 in clusters[c1]:
                    for x2 in clusters[c2]:
                        d = np.linalg.norm(x1-x2)
                        if d > m_d:
                            m_d = d
                    
    return m_d

def dunn(clusters):
    return min_dist(clusters)/max_dist(clusters)

# %%
import math

def Siq(w,X,q=2):
    return math.pow(np.mean([np.linalg.norm(x-w,q) \
                             for x in X]),1/q)

def Dijt(wi,wj,t=2):
    return np.linalg.norm(wi-wj,t)

def Riqt(clusters,centroids,i,q=2,t=2):
    return max(\
           [(Siq(centroids[i],clusters[i],q) +\
            Siq(centroids[j],clusters[j],q))\
            /Dijt(centroids[i],centroids[j],t) for \
              j in clusters.keys()-[i]])

def davies_bouldin(clusters,centroids):
    rs = [\
            Riqt(clusters,centroids,i) for \
            i in clusters]
    
    return np.mean(rs)

# %%
def Bk(centroids,nis,m):
    n = m.shape[0]
    bk = np.zeros((n,n))
    for c,ni in zip(centroids,nis):
        z = (c-m).reshape((1,n))
        bk += ni* (z.T * z)
        
    return bk

def Wk(clusters, centroids):
    n = centroids.shape[1]
    wk = np.zeros((n,n))
    
    for i in clusters:
        for x in clusters[i]:
            z = (x-centroids[i]).reshape(1,n)
            wk += z.T * z
            
    return wk

def calinski_harabasz(clusters, centroids,m):
    k = len(centroids)
    nis = [clusters[i].shape[0] for i in range(k)]

    bk = Bk(centroids,nis,m)
    
    wk = Wk(clusters, centroids)
    
    n = sum(nis)
    
    return (np.trace(bk)/(k-1))/(np.trace(wk)/(n-k))

# %%
df = []
m = np.mean(data,axis=0)
models = {}
for k in range(2,11):
    model = KMeans(n_clusters=k)
    clusters = {i: [] for i in range(k)}
    
    y = model.fit_predict(data)
    models[k] = model
    
    for c,x in zip(y,data):
        clusters[c].append(x)
        
    for c in clusters:
        clusters[c] = np.array(clusters[c])
    
    df.append({
        "1-K":k,
        "2-Dunn": dunn(clusters),
        "3-DB": davies_bouldin(clusters,model.cluster_centers_),
        "4-CH":calinski_harabasz(clusters,model.cluster_centers_,m),
        "5-SL":silhouette_score(data,y)
    })
        
df = pd.DataFrame(df)
df
# Out:
#    1-K    2-Dunn      3-DB         4-CH      5-SL
# 0    2  0.370576  1.359383  1917.547799  0.541584
# 1    3  0.015598  1.065287  2150.362182  0.587314
# 2    4  0.015452  1.075249  4325.263200  0.658898
# 3    5  0.010790  1.363054  4720.415403  0.653328
# 4    6  0.010790  1.509995  6460.105474  0.652840
# 5    7  0.006532  1.743611  6656.942135  0.640673
# 6    8  0.006532  1.883052  6874.657130  0.624277
# 7    9  0.006532  1.805076  7001.546239  0.631121
# 8   10  0.009974  2.062657  6942.918473  0.614515

# %%
df.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
#     #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col0 {
#             background-color:  #f7fbff;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col1 {
#             background-color:  #08306b;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col2 {
#             background-color:  #b8d5ea;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col3 {
#             background-color:  #f7fbff;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col4 {
#             background-color:  #f7fbff;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col0 {
#             background-color:  #deebf7;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col1 {
#             background-color:  #f2f8fd;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col2 {
#             background-color:  #f7fbff;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col3 {
#             background-color:  #eef5fc;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col4 {
#             background-color:  #99c7e0;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col0 {
#             background-color:  #c6dbef;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col1 {
#             background-color:  #f2f8fd;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col2 {
#             background-color:  #f5fafe;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col3 {
#             background-color:  #75b4d8;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col4 {
#             background-color:  #08306b;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col0 {
#             background-color:  #9dcae1;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col1 {
#             background-color:  #f5fafe;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col2 {
#             background-color:  #b7d4ea;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col3 {
#             background-color:  #5aa2cf;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col4 {
#             background-color:  #083c7d;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row4_col0 {
#             background-color:  #6aaed6;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row4_col1 {
#             background-color:  #f5fafe;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row4_col2 {
#             background-color:  #81badb;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row4_col3 {
#             background-color:  #084c95;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row4_col4 {
#             background-color:  #083d7f;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row5_col0 {
#             background-color:  #4191c6;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row5_col1 {
#             background-color:  #f7fbff;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row5_col2 {
#             background-color:  #3383be;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row5_col3 {
#             background-color:  #084285;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row5_col4 {
#             background-color:  #0e58a2;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row6_col0 {
#             background-color:  #2070b4;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row6_col1 {
#             background-color:  #f7fbff;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row6_col2 {
#             background-color:  #135fa7;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row6_col3 {
#             background-color:  #083674;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row6_col4 {
#             background-color:  #2d7dbb;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row7_col0 {
#             background-color:  #08509b;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row7_col1 {
#             background-color:  #f7fbff;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row7_col2 {
#             background-color:  #2373b6;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row7_col3 {
#             background-color:  #08306b;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row7_col4 {
#             background-color:  #1e6db2;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row8_col0 {
#             background-color:  #08306b;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row8_col1 {
#             background-color:  #f5fafe;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row8_col2 {
#             background-color:  #08306b;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row8_col3 {
#             background-color:  #08326e;
#         }    #T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row8_col4 {
#             background-color:  #4292c6;
#         }</style>
# <table id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1-K</th>
#         <th class="col_heading level0 col1" >2-Dunn</th>
#         <th class="col_heading level0 col2" >3-DB</th>
#         <th class="col_heading level0 col3" >4-CH</th>
#         <th class="col_heading level0 col4" >5-SL</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0" class="row_heading level0 row0" >0</th>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col0" class="data row0 col0" >2</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col1" class="data row0 col1" >0.370576</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col2" class="data row0 col2" >1.35938</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col3" class="data row0 col3" >1917.55</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row0_col4" class="data row0 col4" >0.541584</td>
#     </tr>    <tr>
#         <th id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0" class="row_heading level0 row1" >1</th>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col0" class="data row1 col0" >3</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col1" class="data row1 col1" >0.0155981</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col2" class="data row1 col2" >1.06529</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col3" class="data row1 col3" >2150.36</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row1_col4" class="data row1 col4" >0.587314</td>
#     </tr>    <tr>
#         <th id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0" class="row_heading level0 row2" >2</th>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col0" class="data row2 col0" >4</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col1" class="data row2 col1" >0.015452</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col2" class="data row2 col2" >1.07525</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col3" class="data row2 col3" >4325.26</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row2_col4" class="data row2 col4" >0.658898</td>
#     </tr>    <tr>
#         <th id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0" class="row_heading level0 row3" >3</th>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col0" class="data row3 col0" >5</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col1" class="data row3 col1" >0.0107898</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col2" class="data row3 col2" >1.36305</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col3" class="data row3 col3" >4720.42</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row3_col4" class="data row3 col4" >0.653328</td>
#     </tr>    <tr>
#         <th id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0" class="row_heading level0 row4" >4</th>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row4_col0" class="data row4 col0" >6</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac87a33679c0row4_col1" class="data row4 col1" >0.0107898</td>
#         <td id="T_bf1cac30_f1a2_11e8_a955_ac8

# %%
k = 4
model = models[k]
print("{} clusters:".format(k))

y = model.predict(data)

for c in range(k):
    d = data[y==c]
    stats_df = pd.DataFrame(d)
    print("\nC{} - {}\n".format(c, model.cluster_centers_[c]))
    print(stats_df.describe())
# Out:
# 4 clusters:
#
# C0 - [ 0.98284026  0.06229374  0.0290211   0.34959959  0.38158544  0.02654103]
#
#                 0           1           2           3           4           5
# count  428.000000  428.000000  428.000000  428.000000  428.000000  428.000000
# mean     0.982840    0.062294    0.029021    0.349600    0.381585    0.026541
# std      0.074329    0.067237    0.075057    0.130558    0.136900    0.027271
# min      0.250000    0.000000    0.001338    0.060074    0.078269    0.001001
# 25%      1.000000    0.034404    0.003921    0.248633    0.279109    0.008391
# 50%      1.000000    0.044500    0.007545    0.356753    0.389249    0.013594
# 75%      1.000000    0.066055    0.022249    0.460566    0.501039    0.029302
# max      1.000000    1.000000    1.000000    0.593526    0.714286    0.097637
#
# C1 - [ 0.99391971  0.0584906   0.01258958  0.43727342  0.4554304   0.93945604]
#
#                0           1           2           3           4           5
# count  552.00000  552.000000  552.000000  552.000000  552.000000  552.000000
# mean     0.99392    0.058491    0.012590    0.437273    0.455430    0.939456
# std      0.03817    0.031811    0.019969    0.161651    0.162224    0.022430
# min      0.50000    0.000000    0.001269    0.110777    0.122776    0.800410
# 25%      1.00000    0.041284    0.002628    0.301511    0.324606    0.934664
# 50%      1.00000    0.052294    0.005835    0.426401    0.434258    0.937483
# 75%      1.00000    0.068807    0.013172    0.564076    0.577350    0.950714
# max      1.00000    0.337156    0.212861    0.717741    0.768538    0.990543
#
# C2 - [ 0.99002176  0.05644289  0.00209818  0.88502816  0.89588167  0.02365278]
#
#                 0           1           2           3           4           5
# count  383.000000  383.000000  383.000000  383.000000  383.000000  383.000000
# mean     0.990022    0.056443    0.002098    0.885028    0.895882    0.023653
# std      0.084198    0.055188    0.004543    0.154738    0.143877    0.027805
# min      0.000000    0.013761    0.000326    0.564076    0.674200    0.000001
# 25%      1.000000    0.027523    0.000503    0.674200    0.717741    0.008340
# 50%      1.000000    0.041284    0.000899    1.000000    1.000000    0.013056
# 75%      1.000000    0.061927    0.001719    1.000000    1.000000    0.013840
# max      1.000000    0.811927    0.057802    1.000000    1.000000    0.097668
#
# C3 - [ 1.          0.0527489   0.00209837  0.98895213  0.99295975  0.93001803]
#
#            0           1           2           3           4           5
# count  338.0  338.000000  338.000000  338.000000  338.000000  338.000000
# mean     1.0    0.052749    0.002098    0.988952    0.992960    0.930018
# std      0.0    0.043921    0.002711    0.055774    0.037201    0.043302
# min      1.0    0.013761    0.000387    0.674200    0.744803    0.800400
# 25%      1.0    0.027523    0.000661    1.000000    1.000000    0.932146
# 50%      1.0    0.041284    0.001014    1.000000    1.000000    0.937999
# 75%      1.0    0.068807    0.002025    1.000000    1.000000    0.950897
# max      1.0    0.509174    0.016316    1.000000    1.000000    1.000000
